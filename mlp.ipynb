# %% [markdown]
# # Práctica 1: Perceptrón multicapa.
#
# Tu jefe pidió a RH que recolectara datos de desempeño de tus compañeros, los resultados se almacenaron en un csv. El punto critico de estos datos es la satisfacción del empleado, entonces ¿Podremos estimar la satisfacción de los empleados con los datos recabados?.

# %%
import sys
# !{sys.executable} -m pip install pandas matplotlib scikit-learn tensorflow
# Out:
# Collecting pandas
#   Using cached pandas-2.3.3-cp310-cp310-win_amd64.whl (11.3 MB)
# Collecting matplotlib
#   Using cached matplotlib-3.10.8-cp310-cp310-win_amd64.whl (8.1 MB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.7.2-cp310-cp310-win_amd64.whl (8.9 MB)
# Collecting tensorflow
#   Using cached tensorflow-2.20.0-cp310-cp310-win_amd64.whl (331.7 MB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1
#   Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Collecting numpy>=1.22.4
#   Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
# Collecting tzdata>=2022.7
#   Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8
#   Using cached pillow-12.1.0-cp310-cp310-win_amd64.whl (7.0 MB)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.9-cp310-cp310-win_amd64.whl (73 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pyparsing>=3
#   Using cached pyparsing-3.3.1-py3-none-any.whl (121 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.61.1-cp310-cp310-win_amd64.whl (1.6 MB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Collecting threadpoolctl>=3.1.0
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting scipy>=1.8.0
#   Using cached scipy-1.15.3-cp310-cp310-win_amd64.whl (41.3 MB)
# Collecting joblib>=1.2.0
#   Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Using cached gast-0.7.0-py3-none-any.whl (22 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.76.0-cp310-cp310-win_amd64.whl (4.7 MB)
# Collecting tensorboard~=2.20.0
#   Using cached tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
# Collecting requests<3,>=2.21.0
#   Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1
#   Using cached ml_dtypes-0.5.4-cp310-cp310-win_amd64.whl (210 kB)
# Collecting opt_einsum>=2.3.2
#   Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Collecting libclang>=13.0.0
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Collecting flatbuffers>=24.3.25
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from tensorflow) (1.17.0)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-2.3.1-py3-none-any.whl (135 kB)
# Requirement already satisfied: setuptools in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (65.5.0)
# Collecting wrapt>=1.11.0
#   Using cached wrapt-2.0.1-cp310-cp310-win_amd64.whl (60 kB)
# Collecting protobuf>=5.28.0
#   Using cached protobuf-6.33.4-cp310-abi3-win_amd64.whl (436 kB)
# Collecting keras>=3.10.0
#   Using cached keras-3.12.0-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from tensorflow) (4.15.0)
# Collecting google_pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting h5py>=3.11.0
#   Using cached h5py-3.15.1-cp310-cp310-win_amd64.whl (2.9 MB)
# Collecting wheel<1.0,>=0.23.0
#   Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Collecting namex
#   Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Collecting optree
#   Using cached optree-0.18.0-cp310-cp310-win_amd64.whl (302 kB)
# Collecting rich
#   Using cached rich-14.2.0-py3-none-any.whl (243 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Collecting charset_normalizer<4,>=2
#   Using cached charset_normalizer-3.4.4-cp310-cp310-win_amd64.whl (107 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2026.1.4-py3-none-any.whl (152 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.11-py3-none-any.whl (71 kB)
# Collecting markdown>=2.6.8
#   Using cached markdown-3.10-py3-none-any.whl (107 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Collecting werkzeug>=1.0.1
#   Using cached werkzeug-3.1.5-py3-none-any.whl (225 kB)
# Collecting markupsafe>=2.1.1
#   Using cached markupsafe-3.0.3-cp310-cp310-win_amd64.whl (15 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: pytz, namex, libclang, flatbuffers, wrapt, wheel, urllib3, tzdata, threadpoolctl, termcolor, tensorboard-data-server, pyparsing, protobuf, pillow, optree, opt_einsum, numpy, mdurl, markupsafe, markdown, kiwisolver, joblib, idna, grpcio, google_pasta, gast, fonttools, cycler, charset_normalizer, certifi, absl-py, werkzeug, scipy, requests, pandas, ml_dtypes, markdown-it-py, h5py, contourpy, astunparse, tensorboard, scikit-learn, rich, matplotlib, keras, tensorflow
# Successfully installed absl-py-2.3.1 astunparse-1.6.3 certifi-2026.1.4 charset_normalizer-3.4.4 contourpy-1.3.2 cycler-0.12.1 flatbuffers-25.12.19 fonttools-4.61.1 gast-0.7.0 google_pasta-0.2.0 grpcio-1.76.0 h5py-3.15.1 idna-3.11 joblib-1.5.3 keras-3.12.0 kiwisolver-1.4.9 libclang-18.1.1 markdown-3.10 markdown-it-py-4.0.0 markupsafe-3.0.3 matplotlib-3.10.8 mdurl-0.1.2 ml_dtypes-0.5.4 namex-0.1.0 numpy-2.2.6 opt_einsum-3.4.0 optree-0.18.0 pandas-2.3.3 pillow-12.1.0 protobuf-6.33.4 pyparsing-3.3.1 pytz-2025.2 requests-2.32.5 rich-14.2.0 scikit-learn-1.7.2 scipy-1.15.3 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorflow-2.20.0 termcolor-3.3.0 threadpoolctl-3.6.0 tzdata-2025.3 urllib3-2.6.3 werkzeug-3.1.5 wheel-0.45.1 wrapt-2.0.1
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from tensorflow.keras import layers, models


df = pd.read_csv('Extended_Employee_Performance_and_Productivity_Data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Employee_ID                  100000 non-null  int64
#  1   Department                   100000 non-null  object
#  2   Gender                       100000 non-null  object
#  3   Age                          100000 non-null  int64
#  4   Job_Title                    100000 non-null  object
#  5   Hire_Date                    100000 non-null  object
#  6   Years_At_Company             100000 non-null  int64
#  7   Education_Level              100000 non-null  object
#  8   Performance_Score            100000 non-null  int64
#  9   Monthly_Salary               100000 non-null  float64
#  10  Work_Hours_Per_Week          100000 non-null  int64
#  11  Projects_Handled             100000 non-null  int64
#  12  Overtime_Hours               100000 non-null  int64
#  13  Sick_Days                    100000 non-null  int64
#  14  Remote_Work_Frequency        100000 non-null  int64
#  15  Team_Size                    100000 non-null  int64
#  16  Training_Hours               100000 non-null  int64
#  17  Promotions                   100000 non-null  int64
#  18  Employee_Satisfaction_Score  100000 non-null  float64
#  19  Resigned                     100000 non-null  bool
# dtypes: bool(1), float64(2), int64(12), object(5)
# memory usage: 14.6+ MB

# %%
# Filtrar las columnas numéricas
numeric_columns = df.select_dtypes(include=['number']).drop('Employee_ID',axis=1)


# Si numeric_columns es un Index, conviértelo a lista
cols = list(numeric_columns)

fig, axes = plt.subplots(1, len(cols), figsize=(5 * len(cols), 4))

for i, col in enumerate(cols):
    axes[i].hist(df[col], bins=20, color='skyblue', edgecolor='black')
    axes[i].set_title(col)
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Problemas**, tenemos distribuciones con picos, esos nos indica categorías. Por otro lado, tenemos variables con "valles" en su distribución (distribuciones multimodales) por lo que resultaría óptimo aplicar técnicas de feature engeneering. Por último tenemos distribuciones uniformes, por lo que cada una requeriría un procesamiento indivudual, hagamos la vista gorda e intentemos ajustar un MLP con estos datos, solo estandaricemos nuestros datos.

# %% [markdown]
# ---
#
# ## Implementación de Red:
#
# To**memos los datos numéricos como nuestra variable X, y la variable objetivo como ***'Employee_Satisfaction_Score'***.
# - **Actividad 1**: Para todos los strings ``'@modif@'`` que aparescan en el siguiente bloque de código cámbialos para que el código funcione.

# %%
# Variables X e y
X = numeric_columns.drop('Employee_Satisfaction_Score', axis=1)
y = numeric_columns['Employee_Satisfaction_Score']

# Convertimos la variable objetivo a 5 categorías
y = y.apply(lambda x: round(x) - 1)

# Estandarización
scaler = StandardScaler()
X_standar = scaler.fit_transform(X)

# Train / Test split
X_train, X_test, y_train, y_test = train_test_split(
    X_standar, y, test_size=0.33, random_state=42
)

# One-hot encoding
y_onehot_train = tf.keras.utils.to_categorical(y_train, 5)
y_onehot_test = tf.keras.utils.to_categorical(y_test, 5)

# %% [markdown]
# - **Actividad 2:** Implementa 3 arquitecturas de MLP, cada una con su propio nombre, cambiando la estructura de dichas arquitecturas (capas, neuronas por capa, función de activación, etc).

# %%
# En las siguientes celdas, construye tu modelo con tensorflow.keras solo la arquitectura

# %%
model_1 = models.Sequential([
    layers.Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dense(5, activation='softmax')
])
# Out:
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_2 = models.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dense(32, activation='relu'),
    layers.Dense(5, activation='softmax')
])

# %%
model_3 = models.Sequential([
    layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(5, activation='softmax')
])

# %% [markdown]
# - **Actividad 3:** Compila y ajusta tus tres modelos con sus respectivos hiperparámetros.

# %%
# En las siguientes celdas, compila y entrena el modelo

# %%
model_1.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history_1 = model_1.fit(
    X_train, y_onehot_train,
    epochs=30,
    batch_size=32,
    validation_data=(X_test, y_onehot_test)
)
# Out:
# Epoch 1/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.2487 - loss: 1.5720 - val_accuracy: 0.2551 - val_loss: 1.5623
# Epoch 2/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.2558 - loss: 1.5582 - val_accuracy: 0.2528 - val_loss: 1.5598
# Epoch 3/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.2591 - loss: 1.5566 - val_accuracy: 0.2523 - val_loss: 1.5592
# Epoch 4/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.2603 - loss: 1.5558 - val_accuracy: 0.2554 - val_loss: 1.5593
# Epoch 5/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.2624 - loss: 1.5553 - val_accuracy: 0.2539 - val_loss: 1.5595
# Epoch 6/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.2618 - loss: 1.5548 - val_accuracy: 0.2540 - val_loss: 1.5588
# Epoch 7/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.2614 - loss: 1.5546 - val_accuracy: 0.2531 - val_loss: 1.5593
# Epoch 8/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.2649 - loss: 1.5543 - val_accuracy: 0.2559 - val_loss: 1.5586
# Epoch 9/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.2647 - loss: 1.5542 - val_accuracy: 0.2550 - val_loss: 1.5593
# Epoch 10/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - accuracy: 0.2645 - loss: 1.5540 - val_accuracy: 0.2539 - val_loss: 1.5593
# Epoch 11/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.2651 - loss: 1.5538 - val_accuracy: 0.2543 - val_loss: 1.5590
# Epoch 12/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.2659 - loss: 1.5536 - val_accuracy: 0.2540 - val_loss: 1.5598
# Epoch 13/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.2665 - loss: 1.5535 - val_accuracy: 0.2544 - val_loss: 1.5591
# Epoch 14/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.2670 - loss: 1.5536 - val_accuracy: 0.2546 - val_loss: 1.5590
# Epoch 15/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.2655 - loss: 1.5535 - val_accuracy: 0.2549 - val_loss: 1.5594
# Epoch 16/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.2676 - loss: 1.5534 - val_accuracy: 0.2507 - val_loss: 1.5593
# Epoch 17/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.2670 - loss: 1.5532 - val_accuracy: 0.2549 - val_loss: 1.5599
# Epoch 18/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.2690 - loss: 1.5532 - val_accuracy: 0.2527 - val_loss: 1.5591
# Epoch 19/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.2689 - loss: 1.5531 - val_accuracy: 0.2568 - val_loss: 1.5587
# Epoch 20/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.2678 - loss: 1.5529 - val_accuracy: 0.2525 - val_loss: 1.5599
# Epoch 21/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.2705 - loss: 1.5529 - val_accuracy: 0.2555 - val_loss: 1.5600
# Epoch 22/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.2679 - loss: 1.5533 - val_accuracy: 0.2548 - val_loss: 1.5592
# Epoch 23/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.2688 - loss: 1.5531 - val_accuracy: 0.2557 - val_loss: 1.5600
# Epoch 24/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.2690 - loss: 1.5529 - val_accuracy: 0.2541 - val_loss: 1.5595
# Epoch 25/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.2699 - loss: 1.5527 - val_accuracy: 0.2542 - val_loss: 1.5595
# Epoch 26/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.2694 - loss: 1.5527 - val_accuracy: 0.2528 - val_loss: 1.5598
# Epoch 27/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.2712 - loss: 1.5528 - val_accuracy: 0.2539 - val_loss: 1.5599
# Epoch 28/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.2710 - loss: 1.5528 - val_accuracy: 0.2520 - val_loss: 1.5599
# Epoch 29/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.2716 - loss: 1.5527 - val_accuracy: 0.2532 - val_loss: 1.5595
# Epoch 30/30
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.2722 - loss: 1.5526 - val_accuracy: 0.2551 - val_loss: 1.5597

# %% [markdown]
# - **Actividad 4:** Sube tus cambios al repositorio, envía el link de tu repositorio a la actividad 2 de tu checkpoint 2 y contesta las preguntas de dicha actividad.
